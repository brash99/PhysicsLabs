# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# parallel 10x10 data   a    b    c    d    e    f    g    h     i     j
field_map1 = np.array([[1.36,1.52,1.92,2.82,5.08,6.70,8.37,9.89,10.38,10.58],#1
                       [0.98,0.81,0.54,2.70,4.89,6.91,9.42,11.58,11.11,11.0],#2
                       [0.57,0.29,0.00,2.49,4.93,7.30,9.66,12.03,11.70,11.35],#3
                       [0.39,0.16,0.00,2.49,4.98,7.35,9.66,12.03,11.86,11.60],#4
                       [0.29,0.08,0.00,2.46,4.92,7.05,9.70,12.03,11.96,11.67],#5
                       [0.28,0.06,0.00,2.50,4.60,6.87,9.50,12.03,11.94,11.64],#6
                       [0.40,0.14,0.00,2.57,4.58,6.94,9.40,12.03,11.75,11.47],#7
                       [0.64,0.33,0.00,2.62,4.69,6.90,9.45,12.03,11.43,11.16],#8
                       [1.10,1.01,1.22,2.89,5.00,6.88,8.90,10.69,10.68,10.64],#9
                       [1.54,1.76,2.43,3.35,5.14,6.77,8.17,9.30,9.92,10.16]])#10

# point 10x10 data       a   b   c   d   e   f   g   h   i   j
field_map2 = np.array([[3.3,3.7,4.1,4.7,5.5,6.2,7.1,7.6, 8.1, 8.5],#1
                       [3.0,3.4,3.8,4.5,5.5,6.4,7.3,8.0, 8.5, 8.8],#2
                       [2.6,2.9,3.3,4.2,5.4,6.5,7.5,8.5, 9.1, 9.3],#3
                       [2.0,2.0,2.3,3.7,5.3,6.8,8.2,9.5, 9.9, 9.8],#4
                       [1.4,0.5,1.5,3.5,5.4,7.3,9.2,10.5,11.2,10.3],#5
                       [1.4,0.4,1.2,3.4,5.5,7.7,9.4,11.0,11.2,10.4],#6
                       [1.9,2.0,2.7,4.2,5.9,7.6,9.2,9.9, 10.2,10.0],#7
                       [2.6,3.0,3.6,4.7,6.1,7.4,8.6,9.2, 9.6, 9.6],#8
                       [3.2,3.6,4.2,5.2,6.3,7.3,8.2,8.8, 9.2, 9.3],#9
                       [3.6,4.0,4.6,5.5,6.4,7.1,7.9,8.4, 8.9, 9.1]])#10

# mystery 10x10 data     a    b    c    d    e    f    g    h     i     j
field_map3 = np.array([[0.69,2.07,3.21,4.43,5.58,6.66,7.72,8.84,10.03,11.43],#1
                       [0.60,2.04,3.45,4.51,5.67,6.59,7.69,8.86,10.06,11.60],#2
                       [0.57,2.14,3.60,4.92,5.82,6.50,7.43,8.70,9.96,11.64],#3
                       [0.63,2.36,3.94,5.72,6.10,6.11,6.79,8.32,9.92,11.64],#4
                       [0.61,2.52,4.56,6.10,6.10,6.11,6.11,8.07,9.81,11.63],#5
                       [0.64,2.54,4.51,6.10,6.10,6.11,6.11,8.10,9.82,11.54],#6
                       [0.73,2.42,4.17,5.76,6.11,6.12,6.85,8.50,9.88,11.66],#7
                       [0.67,2.32,3.74,5.02,5.88,6.53,7.56,8.72,10.00,11.73],#8
                       [0.62,2.21,3.73,4.80,5.81,6.70,7.74,8.95,10.21,11.69],#9
                       [0.91,2.21,3.51,4.70,5.77,6.77,7.90,9.00,10.11,11.37]])#10

# pretty tedious huh? this is exactly what cameras do everyday.
# show some empathy before you snap. >:(

# define figure
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3,figsize=(20, 9))

# interpolation methods: https://matplotlib.org/stable/gallery/images_contours_and_fields/interpolation_methods.html
# color maps: https://matplotlib.org/stable/tutorials/colors/colormaps.html
im1 = ax1.imshow(field_map1, interpolation='gaussian', cmap='rainbow')
im2 = ax2.imshow(field_map2, interpolation='gaussian', cmap='rainbow')
im3 = ax3.imshow(field_map3, interpolation='gaussian', cmap='rainbow')

# add contor lines
cs1 = ax1.contour(field_map1, 12)
cs2 = ax2.contour(field_map2, 12)
cs3 = ax3.contour(field_map3, 12)

# label every other contor lines
strs = ['0V','1V','2V','3V','4V','5V','6V','7V','8V','9V','10V','11V','12V']

fmt1 = {}
fmt2 = {}
fmt3 = {}

for l, s in zip(cs1.levels, strs):
    fmt1[l] = s
for l, s in zip(cs2.levels, strs):
    fmt2[l] = s
for l, s in zip(cs3.levels, strs):
    fmt3[l] = s

ax1.clabel(cs1, cs1.levels[::2], inline=True, fmt=fmt1, fontsize=10)
ax2.clabel(cs2, cs2.levels[::2], inline=True, fmt=fmt2, fontsize=10)
ax3.clabel(cs3, cs2.levels[::2], inline=True, fmt=fmt3, fontsize=10)

# uncomment to show actual voltage values
'''
for i in range(10):
    for j in range(10):
        text1 = ax1.text(j, i, field_map1[i, j],
                         ha="center", va="center", color="w")
        text2 = ax2.text(j, i, field_map2[i, j],
                         ha="center", va="center", color="w")
        text3 = ax3.text(j, i, field_map3[i, j],
                         ha="center", va="center", color="w")
'''

# formatting stuff
ax1.set_title('two point field',fontsize=20)
ax1.tick_params(axis='x', colors='white')
ax1.tick_params(axis='y', colors='white')
ax1.title.set_color('white')

ax2.set_title('parallel plate field',fontsize=20)
ax2.tick_params(axis='x', colors='white')
ax2.tick_params(axis='y', colors='white')
ax2.title.set_color('white')

ax3.set_title('mystery field',fontsize=20)
ax3.tick_params(axis='x', colors='white')
ax3.tick_params(axis='y', colors='white')
ax3.title.set_color('white')

fig.tight_layout()
plt.show()

# %%
# intuitive potential difference analog (looks like hill)

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm


fig2 = plt.figure()
ax = fig2.add_subplot(111, projection='3d')

X = [[i for j in range(10)] for i in range(10)]
Y = [[j for j in range(10)] for i in range(10)]
Z = field_map2


# Plot a basic wireframe
ax.plot_surface(X,Y,Z, cmap=cm.rainbow, rstride=1, cstride=1)
#ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)

# change the prams to rotate the plot (pitch (deg)+up -down, yaw (deg)+cw -ccw
#ax.view_init(20, 20)
#plt.show()

for ii in range(0, 360):
    ax.view_init(30, ii)
    plt.savefig("frames/movie{}.png".format(ii))

# %%
# %%bash
# ffmpeg -r 30 -i frames/movie%d.png -c:v libx264 -vf fps=25 -pix_fmt yuv420p out2.mp4
#
# %%bash
# rm frames/*.png
# Out:
# ffmpeg version 2.8.15 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 4.8.5 (GCC) 20150623 (Red Hat 4.8.5-36)
#   configuration: --prefix=/usr --bindir=/usr/bin --datadir=/usr/share/ffmpeg --incdir=/usr/include/ffmpeg --libdir=/usr/lib64 --mandir=/usr/share/man --arch=x86_64 --optflags='-O2 -g -pipe -Wall -Wp,-D_FORTIFY_SOURCE=2 -fexceptions -fstack-protector-strong --param=ssp-buffer-size=4 -grecord-gcc-switches -m64 -mtune=generic' --extra-ldflags='-Wl,-z,relro ' --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libvo-amrwbenc --enable-version3 --enable-bzlib --disable-crystalhd --enable-gnutls --enable-ladspa --enable-libass --enable-libcdio --enable-libdc1394 --enable-libfdk-aac --enable-nonfree --disable-indev=jack --enable-libfreetype --enable-libgsm --enable-libmp3lame --enable-openal --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-libschroedinger --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libvorbis --enable-libv4l2 --enable-libx264 --enable-libx265 --enable-libxvid --enable-x11grab --enable-avfilter --enable-avresample --enable-postproc --enable-pthreads --disable-static --enable-shared --enable-gpl --disable-debug --disable-stripping --shlibdir=/usr/lib64 --enable-runtime-cpudetect
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, image2, from 'frames/movie%d.png':
#   Duration: 00:00:14.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 432x288 [SAR 2834:2834 DAR 3:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# [libx264 @ 0x171bb20] using SAR=1/1
# [libx264 @ 0x171bb20] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX AVX2 FMA3 LZCNT BMI2
# [libx264 @ 0x171bb20] profile High, level 2.1
# [libx264 @ 0x171bb20] 264 - core 142 r2495 6a301b6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2014 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=30 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'out2.mp4':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: h264 (libx264) ([33][0][0][0] / 0x0021), yuv420p, 432x288 [SAR 1:1 DAR 3:2], q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [AVIOContext @ 0x146d7e0] Statistics: 30393 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=13.920  pts=13.920
#   size=30393
# [libx264 @ 0x171bb20] frame= 203 QP=20.82 NAL=2 Slice:P Poc:410 I:8    P:199  SKIP:279  size=2639 bytes
# [AVIOContext @ 0x147e720] Statistics: 30019 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=13.960  pts=13.960
#   size=30019
# [Parsed_fps_0 @ 0x1495140] Dropping 1 frame(s).
# [AVIOContext @ 0x146d7e0] Statistics: 29435 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.000  pts=14.000
#   size=29435
# [libx264 @ 0x171bb20] frame= 204 QP=27.56 NAL=2 Slice:B Poc:408 I:0    P:164  SKIP:309  size=607 bytes
# [AVIOContext @ 0x147e720] Statistics: 29082 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.040  pts=14.040
#   size=29082
# [libx264 @ 0x171bb20] frame= 205 QP=26.88 NAL=0 Slice:B Poc:406 I:0    P:162  SKIP:309  size=642 bytes
# [AVIOContext @ 0x146d800] Statistics: 28289 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.080  pts=14.080
#   size=28289
# [libx264 @ 0x171bb20] frame= 206 QP=23.05 NAL=2 Slice:P Poc:416 I:15   P:194  SKIP:277  size=2570 bytes
# [AVIOContext @ 0x147e720] Statistics: 27506 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.120  pts=14.120
#   size=27506
# [libx264 @ 0x171bb20] frame= 207 QP=27.48 NAL=2 Slice:B Poc:414 I:0    P:147  SKIP:318  size=585 bytes
# [AVIOContext @ 0x14a0e60] Statistics: 26775 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.160  pts=14.160
#   size=26775
# [libx264 @ 0x171bb20] frame= 208 QP=26.70 NAL=0 Slice:B Poc:412 I:1    P:135  SKIP:330  size=556 bytes
# [AVIOContext @ 0x14a0e60] Statistics: 25625 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.200  pts=14.200
#   size=25625
# [Parsed_fps_0 @ 0x1495140] Dropping 1 frame(s).
# [AVIOContext @ 0x14a0e60] Statistics: 24523 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.240  pts=14.240
#   size=24523
# [libx264 @ 0x171bb20] frame= 209 QP=24.33 NAL=2 Slice:P Poc:424 I:13   P:187  SKIP:286  size=2512 bytes
# [AVIOContext @ 0x14a0e60] Statistics: 23535 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.280  pts=14.280
#   size=23535
# [libx264 @ 0x171bb20] frame= 210 QP=25.20 NAL=2 Slice:B Poc:420 I:0    P:144  SKIP:311  size=850 bytes
# [AVIOContext @ 0x14a0ec0] Statistics: 22195 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.320  pts=14.320
#   size=22195
# [libx264 @ 0x171bb20] frame= 211 QP=26.81 NAL=0 Slice:B Poc:418 I:0    P:149  SKIP:330  size=537 bytes
# [AVIOContext @ 0x14a0ec0] Statistics: 21384 bytes read, 0 seeks
# stream #0:
#   keyframe=1
#   duration=0.040
#   dts=14.360  pts=14.360
#   size=21384
# [libx264 @ 0x171bb20] frame= 212 QP=27.60 NAL=0 Slice:B Poc:422 I:1    P:142  SKIP:328  size=542 bytes
# [libx264 @ 0x171bb20] frame= 213 QP=19.15 NAL=2 Slice:P Poc:430 I:9    P:189  SKIP:288  size=2549 bytes
# [Parsed_fps_0 @ 0x1495140] Dropping 1 frame(s).
# [libx264 @ 0x171bb20] frame= 214 QP=27.73 NAL=2 Slice:B Poc:428 I:0    P:139  SKIP:321  size=691 bytes
# [libx264 @ 0x171bb20] frame= 215 QP=27.61 NAL=0 Slice:B Poc:426 I:1    P:143  SKIP:321  size=640 bytes
# [libx264 @ 0x171bb20] frame= 216 QP=21.56 NAL=2 Slice:P Poc:436 I:13   P:180  SKIP:293  size=2527 bytes
# [libx264 @ 0x171bb20] frame= 217 QP=27.32 NAL=2 Slice:B Poc:434 I:0    P:132  SKIP:322  size=708 bytes
# [libx264 @ 0x171bb20] frame= 218 QP=27.52 NAL=0 Slice:B Poc:432 I:1    P:124  SKIP:340  size=627 bytes
# [Parsed_fps_0 @ 0x1495140] Dropping 1 frame(s).
# [libx264 @ 0x171bb20] frame= 219 QP=21.13 NAL=2 Slice:P Poc:442 I:19   P:167  SKIP:300  size=2211 bytes
# [libx264 @ 0x171bb20] frame= 220 QP=26.57 NAL=2 Slice:B Poc:440 I:0    P:114  SKIP:348  size=740 bytes
# [libx264 @ 0x171bb20] frame= 221 QP=26.27 NAL=0 Slice:B Poc:438 I:0    P:121  SKIP:343  size=627 bytes
# [libx264 @ 0x171bb20] frame= 222 QP=25.00 NAL=2 Slice:P Poc:448 I:46   P:137  SKIP:303  size=2331 bytes
# [libx264 @ 0x171bb20] frame= 223 QP=28.03 NAL=2 Slice:B Poc:446 I:5    P:124  SKIP:338  size=779 bytes
# [Parsed_fps_0 @ 0x1495140] Dropping 1 frame(s).
# [libx264 @ 0x171bb20] frame= 224 QP=27.00 NAL=0 Slice:B Poc:444 I:1    P:135  SKIP:332  size=749 bytes
# [libx264 @ 0x171bb20] frame= 225 QP=23.77 NAL=2 Slice:P Poc:454 I:50   P:123  SKIP:313  size=2935 bytes
# [output stream 0:0 @ 0x170d6e0] EOF on sink link output stream 0:0:default.
# No more output streams to write to, finishing.
# [libx264 @ 0x171bb20] frame= 226 QP=27.88 NAL=2 Slice:B Poc:452 I:9    P:130  SKIP:334  size=878 bytes
# [libx264 @ 0x171bb20] frame= 227 QP=28.02 NAL=0 Slice:B Poc:450 I:6    P:113  SKIP:354  size=768 bytes
# [libx264 @ 0x171bb20] frame= 228 QP=24.85 NAL=2 Slice:P Poc:460 I:16   P:163  SKIP:307  size=2565 bytes
# [libx264 @ 0x171bb20] frame= 229 QP=27.58 NAL=2 Slice:B Poc:458 I:0    P:143  SKIP:324  size=778 bytes
# [libx264 @ 0x171bb20] frame= 230 QP=26.84 NAL=0 Slice:B Poc:456 I:0    P:124  SKIP:347  size=777 bytes
# [libx264 @ 0x171bb20] frame= 231 QP=21.47 NAL=2 Slice:P Poc:466 I:16   P:172  SKIP:298  size=3099 bytes
# [libx264 @ 0x171bb20] frame= 232 QP=27.41 NAL=2 Slice:B Poc:464 I:1    P:135  SKIP:318  size=775 bytes
# [libx264 @ 0x171bb20] frame= 233 QP=27.67 NAL=0 Slice:B Poc:462 I:0    P:122  SKIP:346  size=599 bytes
# [libx264 @ 0x171bb20] frame= 234 QP=22.47 NAL=2 Slice:P Poc:472 I:7    P:189  SKIP:290  size=2585 bytes
# [libx264 @ 0x171bb20] frame= 235 QP=28.24 NAL=2 Slice:B Poc:470 I:1    P:137  SKIP:325  size=665 bytes
# [libx264 @ 0x171bb20] frame= 236 QP=27.45 NAL=0 Slice:B Poc:468 I:0    P:126  SKIP:332  size=653 bytes
# [libx264 @ 0x171bb20] frame= 237 QP=23.47 NAL=2 Slice:P Poc:478 I:8    P:190  SKIP:288  size=2790 bytes
# [libx264 @ 0x171bb20] frame= 238 QP=27.87 NAL=2 Slice:B Poc:476 I:0    P:153  SKIP:313  size=715 bytes
# [libx264 @ 0x171bb20] frame= 239 QP=26.71 NAL=0 Slice:B Poc:474 I:1    P:148  SKIP:318  size=707 bytes
# [libx264 @ 0x171bb20] frame= 240 QP=23.41 NAL=2 Slice:P Poc:484 I:8    P:185  SKIP:293  size=2588 bytes
# [libx264 @ 0x171bb20] frame= 241 QP=26.19 NAL=2 Slice:B Poc:482 I:1    P:142  SKIP:319  size=583 bytes
# [libx264 @ 0x171bb20] frame= 242 QP=27.13 NAL=0 Slice:B Poc:480 I:1    P:133  SKIP:332  size=553 bytes
# [libx264 @ 0x171bb20] frame= 243 QP=22.25 NAL=2 Slice:P Poc:486 I:8    P:185  SKIP:293  size=2138 bytes
# [libx264 @ 0x171bb20] frame= 244 QP=19.52 NAL=2 Slice:P Poc:492 I:6    P:197  SKIP:283  size=2470 bytes
# [libx264 @ 0x171bb20] frame= 245 QP=27.13 NAL=2 Slice:B Poc:490 I:0    P:151  SKIP:311  size=554 bytes
# [libx264 @ 0x171bb20] frame= 246 QP=28.30 NAL=0 Slice:B Poc:488 I:0    P:153  SKIP:319  size=501 bytes
# [libx264 @ 0x171bb20] frame= 247 QP=19.30 NAL=2 Slice:P Poc:494 I:8    P:183  SKIP:295  size=2003 bytes
# [libx264 @ 0x171bb20] frame= 248 QP=25.17 NAL=2 Slice:P Poc:498 I:6    P:183  SKIP:297  size=1009 bytes
# [libx264 @ 0x171bb20] frame= 249 QP=28.07 NAL=0 Slice:B Poc:496 I:0    P:165  SKIP:298  size=637 bytes
# [libx264 @ 0x171bb20] frame= 250 QP=13.34 NAL=3 Slice:I Poc:0   I:486  P:0    SKIP:0    size=9792 bytes
# [libx264 @ 0x171bb20] frame= 251 QP=18.08 NAL=2 Slice:P Poc:6   I:8    P:206  SKIP:272  size=2655 bytes
# [libx264 @ 0x171bb20] frame= 252 QP=27.66 NAL=2 Slice:B Poc:4   I:0    P:177  SKIP:290  size=812 bytes
# [libx264 @ 0x171bb20] frame= 253 QP=26.08 NAL=0 Slice:B Poc:2   I:1    P:144  SKIP:316  size=576 bytes
# [libx264 @ 0x171bb20] frame= 254 QP=22.47 NAL=2 Slice:P Poc:14  I:4    P:209  SKIP:273  size=2727 bytes
# [libx264 @ 0x171bb20] frame= 255 QP=25.40 NAL=2 Slice:B Poc:10  I:0    P:170  SKIP:285  size=843 bytes
# [libx264 @ 0x171bb20] frame= 256 QP=26.54 NAL=0 Slice:B Poc:8   I:0    P:155  SKIP:315  size=615 bytes
# [libx264 @ 0x171bb20] frame= 257 QP=25.86 NAL=0 Slice:B Poc:12  I:1    P:156  SKIP:306  size=648 bytes
# [libx264 @ 0x171bb20] frame= 258 QP=23.56 NAL=2 Slice:P Poc:20  I:6    P:213  SKIP:267  size=2899 bytes
# [libx264 @ 0x171bb20] frame= 259 QP=27.70 NAL=2 Slice:B Poc:18  I:0    P:173  SKIP:293  size=593 bytes
# [libx264 @ 0x171bb20] frame= 260 QP=25.84 NAL=0 Slice:B Poc:16  I:1    P:171  SKIP:293  size=657 bytes
# [libx264 @ 0x171bb20] frame= 261 QP=22.05 NAL=2 Slice:P Poc:26  I:6    P:213  SKIP:267  size=2817 bytes
# [libx264 @ 0x171bb20] frame= 262 QP=27.58 NAL=2 Slice:B Poc:24  I:1    P:159  SKIP:296  size=768 bytes
# [libx264 @ 0x171bb20] frame= 263 QP=27.48 NAL=0 Slice:B Poc:22  I:0    P:156  SKIP:313  size=534 bytes
# [libx264 @ 0x171bb20] frame= 264 QP=20.11 NAL=2 Slice:P Poc:34  I:6    P:211  SKIP:269  size=2669 bytes
# [libx264 @ 0x171bb20] frame= 265 QP=26.15 NAL=2 Slice:B Poc:30  I:3    P:165  SKIP:284  size=956 bytes
# [libx264 @ 0x171bb20] frame= 266 QP=27.89 NAL=0 Slice:B Poc:28  I:0    P:156  SKIP:307  size=546 bytes
# [libx264 @ 0x171bb20] frame= 267 QP=27.58 NAL=0 Slice:B Poc:32  I:4    P:151  SKIP:302  size=540 bytes
# [libx264 @ 0x171bb20] frame= 268 QP=19.14 NAL=2 Slice:P Poc:40  I:12   P:206  SKIP:268  size=2821 bytes
# [libx264 @ 0x171bb20] frame= 269 QP=26.78 NAL=2 Slice:B Poc:38  I:0    P:165  SKIP:288  size=698 bytes
# [libx264 @ 0x171bb20] frame= 270 QP=25.46 NAL=0 Slice:B Poc:36  I:0    P:171  SKIP:290  size=682 bytes
# [libx264 @ 0x171bb20] frame= 271 QP=22.43 NAL=2 Slice:P Poc:46  I:6    P:210  SKIP:270  size=2876 bytes
# [libx264 @ 0x171bb20] frame= 272 QP=27.28 NAL=2 Slice:B Poc:44  I:2    P:152  SKIP:298  size=727 bytes
# [libx264 @ 0x171bb20] frame= 273 QP=25.98 NAL=0 Slice:B Poc:42  I:0    P:162  SKIP:307  size=555 bytes
# [libx264 @ 0x171bb20] frame= 274 QP=24.32 NAL=2 Slice:P Poc:54  I:9    P:204  SKIP:273  size=2402 bytes
# [libx264 @ 0x171bb20] frame= 275 QP=26.10 NAL=2 Slice:B Poc:50  I:0    P:163  SKIP:290  size=885 bytes
# [libx264 @ 0x171bb20] frame= 276 QP=28.12 NAL=0 Slice:B Poc:48  I:1    P:150  SKIP:314  size=604 bytes
# [libx264 @ 0x171bb20] frame= 277 QP=25.84 NAL=0 Slice:B Poc:52  I:1    P:148  SKIP:310  size=652 bytes
# [libx264 @ 0x171bb20] frame= 278 QP=18.04 NAL=2 Slice:P Poc:60  I:9    P:197  SKIP:280  size=2823 bytes
# [libx264 @ 0x171bb20] frame= 279 QP=27.35 NAL=2 Slice:B Poc:58  I:0    P:165  SKIP:296  size=754 bytes
# [libx264 @ 0x171bb20] frame= 280 QP=27.53 NAL=0 Slice:B Poc:56  I:3    P:153  SKIP:298  size=784 bytes
# [libx264 @ 0x171bb20] frame= 281 QP=23.68 NAL=2 Slice:P Poc:66  I:7    P:197  SKIP:282  size=2693 bytes
# [libx264 @ 0x171bb20] frame= 282 QP=26.78 NAL=2 Slice:B Poc:64  I:1    P:149  SKIP:304  size=826 bytes
# [libx264 @ 0x171bb20] frame= 283 QP=27.33 NAL=0 Slice:B Poc:62  I:0    P:137  SKIP:320  size=625 bytes
# [libx264 @ 0x171bb20] frame= 284 QP=25.20 NAL=2 Slice:P Poc:72  I:6    P:187  SKIP:293  size=2100 bytes
# [libx264 @ 0x171bb20] frame= 285 QP=27.03 NAL=2 Slice:B Poc:70  I:0    P:149  SKIP:304  size=690 bytes
# [libx264 @ 0x171bb20] frame= 286 QP=26.87 NAL=0 Slice:B Poc:68  I:0    P:128  SKIP:322  size=613 bytes
# [libx264 @ 0x171bb20] frame= 287 QP=20.15 NAL=2 Slice:P Poc:74  I:8    P:184  SKIP:294  size=1542 bytes
# [libx264 @ 0x171bb20] frame= 288 QP=18.86 NAL=2 Slice:P Poc:76  I:10   P:182  SKIP:294  size=2001 bytes
# [libx264 @ 0x171bb20] frame= 289 QP=19.51 NAL=2 Slice:P Poc:82  I:21   P:173  SKIP:292  size=2440 bytes
# [libx264 @ 0x171bb20] frame= 290 QP=27.53 NAL=2 Slice:B Poc:80  I:2    P:149  SKIP:306  size=767 bytes
# [libx264 @ 0x171bb20] frame= 291 QP=27.72 NAL=0 Slice:B Poc:78  I:1    P:136  SKIP:318  size=670 bytes
# [libx264 @ 0x171bb20] frame= 292 QP=22.70 NAL=2 Slice:P Poc:88  I:23   P:167  SKIP:296  size=2565 bytes
# [libx264 @ 0x171bb20] frame= 293 QP=25.95 NAL=2 Slice:B Poc:86  I:0    P:145  SKIP:312  size=957 bytes
# [libx264 @ 0x171bb20] frame= 294 QP=25.70 NAL=0 Slice:B Poc:84  I:0    P:153  SKIP:316  size=724 bytes
# [libx264 @ 0x171bb20] frame= 295 QP=22.26 NAL=2 Slice:P Poc:94  I:31   P:150  SKIP:305  size=1767 bytes
# [libx264 @ 0x171bb20] frame= 296 QP=27.18 NAL=2 Slice:B Poc:92  I:2    P:127  SKIP:314  size=895 bytes
# [libx264 @ 0x171bb20] frame= 297 QP=28.35 NAL=0 Slice:B Poc:90  I:0    P:136  SKIP:322  size=856 bytes
# [libx264 @ 0x171bb20] frame= 298 QP=26.26 NAL=2 Slice:P Poc:98  I:48   P:127  SKIP:311  size=1336 bytes
# [libx264 @ 0x171bb20] frame= 299 QP=27.91 NAL=0 Slice:B Poc:96  I:5    P:154  SKIP:315  size=891 bytes
# frame=  300 fps=0.0 q=-1.0 L00000000000000000000000000000000size=     432kB time=00:00:11.92 bitrate= 296.9kbits/s
# video:428kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.008397%
# Input file #0 (frames/movie%d.png):
#   Input stream #0:0 (video): 360 packets read (10954023 bytes); 360 frames decoded;
#   Total: 360 packets (10954023 bytes) demuxed
# Output file #0 (out2.mp4):
#   Output stream #0:0 (video): 300 frames encoded; 300 packets muxed (437923 bytes);
#   Total: 300 packets (437923 bytes) muxed
# 360 frames successfully decoded, 0 decoding errors
# [Parsed_fps_0 @ 0x1495140] 360 frames in, 300 frames out; 60 frames dropped, 0 frames duplicated.
# [AVIOContext @ 0x172b520] Statistics: 34 seeks, 326 writeouts
# [libx264 @ 0x171bb20] frame I:2     Avg QP:18.52  size:  6956
# [libx264 @ 0x171bb20] frame P:109   Avg QP:22.23  size:  2598
# [libx264 @ 0x171bb20] frame B:189   Avg QP:26.96  size:   741
# [libx264 @ 0x171bb20] consecutive B-frames:  5.3%  6.0% 78.0% 10.7%
# [libx264 @ 0x171bb20] mb I  I16..4: 37.7% 29.3% 33.0%
# [libx264 @ 0x171bb20] mb P  I16..4:  0.6%  1.0%  1.2%  P16..4:  9.6% 14.6% 14.2%  0.0%  0.0%    skip:58.8%
# [libx264 @ 0x171bb20] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 18.6% 12.2%  4.0%  direct: 1.8%  skip:63.2%  L0:35.7% L1:47.6% BI:16.7%
# [libx264 @ 0x171bb20] 8x8 transform intra:34.3% inter:16.3%
# [libx264 @ 0x171bb20] coded y,uvDC,uvAC intra: 30.8% 9.0% 7.6% inter: 6.8% 3.8% 2.8%
# [libx264 @ 0x171bb20] i16 v,h,dc,p: 49% 39% 11%  0%
# [libx264 @ 0x171bb20] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23%  7% 67%  1%  0%  0%  0%  1%  1%
# [libx264 @ 0x171bb20] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 30% 20%  3%  1%  2%  3%  4%  3%
# [libx264 @ 0x171bb20] i8c dc,h,v,p: 90%  5%  3%  1%
# [libx264 @ 0x171bb20] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x171bb20] ref P L0: 69.2%  8.0% 17.8%  5.0%
# [libx264 @ 0x171bb20] ref B L0: 82.3% 16.0%  1.7%
# [libx264 @ 0x171bb20] ref B L1: 86.5% 13.5%
# [libx264 @ 0x171bb20] kb/s:291.49
